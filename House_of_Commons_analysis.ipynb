# %% [markdown]
# This model will analyse and determine topics for categorising voter to a MP using the House of Commons Oral and Written Questions data set

# %%
import pandas as pd
import json
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import json

# Load and inspect the Questions by Party data
with open('/content/questions_by_party.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# {'Conservative': ['If her Department will make an assessment of the potential merits of excluding charity lotteries from the proposed gambling levy.', 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to encourage church choirs to engage with local schools.', 'If she will make a statement on her departmental responsibilities.', 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what recent assessment the Church of England has made of the potential merits of recruiting additional ordained Ministers into Parish Ministry in the Diocese of Exeter.', 'If she will make a statement on her departmental responsibilities.', 'What assessment her Department has made of the potential impact of the gambling white paper on the horse racing sector.', 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to support parish life in small, rural communities.', 'Whether she is taking steps with the Secretary of State for Transport to celebrate the 200th anniversary of the passenger railway.', 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to support family relationships, parenting and marriage following the report of the Archbishops’ commission on families and households.', 'If she will make a statement on her departmental responsibilities.', 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to use Diocesan Clergy Stipend funds.', 'What recent assessment she has made of the potential impact of the Youth Investment Fund on youth facilities and services.', 'What plans she has for the future of the TV licence.', 'What recent assessment she has made of the potential impact of the Youth Investment Fund on youth facilities and services.', 'What recent discussions she has had with the Gambling Commission on the potential impact on prize draws and competitions of the provisions in the gambling white paper.', 'What representations she has received on increasing fundraising limits for charity lotteries.', 'What steps her Department is taking to support the provision of youth services.', 'If she will take steps to end the TV licence.', 'If he will make a statement on his departmental responsibilities.', 'What steps his Department is taking to help fill vacancies and increase employment in Adur and Worthing.', 'What steps his Department is taking to improve workplace support for women experiencing menopause.', 'What proportion of the population is economically inactive.', 'If he will make a statement on his departmental responsibilities.', 'What steps his Department is taking to increase employment in Don Valley.', 'What steps his Department is taking to improve social mobility among young people.', 'What steps his Department is taking to tackle benefit fraud.', 'What steps he is taking to ensure that the benefits system incentivises work.', 'What steps he is taking to encourage eligible pensioners to claim Pension Credit.', 'What recent assessment he has made of the adequacy of funding for defined benefit pension schemes.', 'What proportion of the population is economically inactive.', 'What steps his Department is taking to improve social mobility among young people.', 'What steps his Department is taking to help fill vacancies and increase employment in Keighley and Ilkley.', 'What steps his Department is taking to increase employment in Sandwell.', 'If he will make a statement on his departmental responsibilities.', 'If he will make a statement on his departmental responsibilities.', 'What steps he is taking to support consumers of financial services who have not received compensation in cases where action by a third party has led to financial loss.', 'Whether his Department is taki ...
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# The data must be transformed to create a dataframe for topic and sentiment analysis
transformed_data = []

for party, questions in data.items():
    for question in questions:
        transformed_data.append({"Party": party, "Question": question})

print(transformed_data)
# Out:
# [{'Party': 'Conservative', 'Question': 'If her Department will make an assessment of the potential merits of excluding charity lotteries from the proposed gambling levy.'}, {'Party': 'Conservative', 'Question': 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to encourage church choirs to engage with local schools.'}, {'Party': 'Conservative', 'Question': 'If she will make a statement on her departmental responsibilities.'}, {'Party': 'Conservative', 'Question': 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what recent assessment the Church of England has made of the potential merits of recruiting additional ordained Ministers into Parish Ministry in the Diocese of Exeter.'}, {'Party': 'Conservative', 'Question': 'If she will make a statement on her departmental responsibilities.'}, {'Party': 'Conservative', 'Question': 'What assessment her Department has made of the potential impact of the gambling white paper on the horse racing sector.'}, {'Party': 'Conservative', 'Question': 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to support parish life in small, rural communities.'}, {'Party': 'Conservative', 'Question': 'Whether she is taking steps with the Secretary of State for Transport to celebrate the 200th anniversary of the passenger railway.'}, {'Party': 'Conservative', 'Question': 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to support family relationships, parenting and marriage following the report of the Archbishops’ commission on families and households.'}, {'Party': 'Conservative', 'Question': 'If she will make a statement on her departmental responsibilities.'}, {'Party': 'Conservative', 'Question': 'To ask the hon. Member for South West Bedfordshire, representing the Church Commissioners, what steps the Church of England is taking to use Diocesan Clergy Stipend funds.'}, {'Party': 'Conservative', 'Question': 'What recent assessment she has made of the potential impact of the Youth Investment Fund on youth facilities and services.'}, {'Party': 'Conservative', 'Question': 'What plans she has for the future of the TV licence.'}, {'Party': 'Conservative', 'Question': 'What recent assessment she has made of the potential impact of the Youth Investment Fund on youth facilities and services.'}, {'Party': 'Conservative', 'Question': 'What recent discussions she has had with the Gambling Commission on the potential impact on prize draws and competitions of the provisions in the gambling white paper.'}, {'Party': 'Conservative', 'Question': 'What representations she has received on increasing fundraising limits for charity lotteries.'}, {'Party': 'Conservative', 'Question': 'What steps her Department is taking to support the provision of youth services.'}, {'Party': 'Conservative', 'Question': 'If she will take steps to end the TV licence.'}, {'Party': 'Conservative', 'Question': 'If he will make a statement on his departmental responsibilities.'}, {'Party': 'Conservative', 'Question': 'What steps his Department is taking to help fill vacancies and increase employment in Adur and Worthing.'}, {'Party': 'Conservative', 'Question': 'What steps his Department is taking to improve workplace support for women experiencing menopause.'}, {'Party': 'Conservative', 'Question': 'What proportion of the population is economically inactive.'}, {'Party': 'Conservative', 'Question': 'If he will make a statement on his departmental responsibilities.'}, {'Party': 'Conservative', 'Question': 'What steps his Department is taking to increase employment in Don Valley.'}, {'Party': 'Conservative', 'Question': 'What steps his Department is taking to improve social mobility among young people.'}, {'Party': 'Conservative', 'Question': 'What step ...
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.DataFrame(transformed_data)

display(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          Party  \
# 0                 Conservative
# 1                 Conservative
# 2                 Conservative
# 3                 Conservative
# 4                 Conservative
# ...                        ...
# 4459  Workers Party of Britain
# 4460  Workers Party of Britain
# 4461  Workers Party of Britain
# 4462  Workers Party of Britain
# 4463  Workers Party of Britain
#
#                                                Question
# 0     If her Department will make an assessment of t...
# 1     To ask the hon. Member for South West Bedfords...
# 2     If she will make a statement on her department...
# 3     To ask the hon. Member for South West Bedfords...
# 4     If she will make a statement on her department...
# ...                                                 ...
# 4459  If she will have discussions with the Secretar...
# 4460  If she will make a statement on her department...
# 4461  What recent discussions he has had with Avanti...
# 4462  If he will make a statement on his departmenta...
# 4463  To ask the hon. Member for Luton South, repres...
#
# [4464 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

stop_words = list(ENGLISH_STOP_WORDS)

vectorizer = TfidfVectorizer(stop_words=stop_words, max_df=0.95, min_df=2)
X = vectorizer.fit_transform(df['Question'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# NMF for topic modelling
n_topics = 5

nmf = NMF(n_components=n_topics)
nmf.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# NMF(n_components=5)

# %%
def display_topics(model, feature_names, num_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))

num_top_words = 30
feature_names = vectorizer.get_feature_names_out()

print("\nNMF Topics:")
display_topics(nmf, feature_names, num_top_words)
# Out:
# NMF Topics:
# Topic 1:
# departmental responsibilities statement make policy merits government public potential autumn portfolio ownership ministers assessment economy impact support estimate productivity airport solar scottish scheme heathrow visa gender devolving panels sentences report
# Topic 2:
# wednesday engagements list official january february march july 13 november 22 15 september december 28 21 24 april 17 june october 29 19 31 10 18 25 20 12 2023
# Topic 3:
# steps taking department support help increase reduce improve tackle ensure veterans people sector children fiscal businesses women number taken energy crime services access small work needs victims violence girls connectivity
# Topic 4:
# assessment recent impact potential adequacy policies level department trends implications effectiveness levels uk living merits food progress increases cost economy service local eu funding strength inflation services rates tax public
# Topic 5:
# cabinet colleagues discussions recent cost living wales scotland government scottish northern ireland increases support households impact people industry energy future welsh held state businesses secretary steelmaking taken potential international supporting
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
